# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, roc_auc_score, classification_report, log_loss, make_scorer, f1_score
import pandas as pd
from sklearn.model_selection import GridSearchCV, train_test_split
import sklearn
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Input, InputLayer
from tensorflow.keras import optimizers
import tensorflow.keras.backend as K
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow.keras.backend as K
from tensorflow.keras.applications import nasnet, resnet50, densenet

# %matplotlib inline

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        rotation_range=20,
        horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_gen = train_datagen.flow_from_directory(
        'train',
        target_size=(150, 150),
        batch_size=6,
        class_mode='binary',
        shuffle=True)

val_gen = val_datagen.flow_from_directory(
        'val',
        target_size=(150, 150),
        batch_size=6,
        class_mode='binary',
        shuffle=True)

test_gen = test_datagen.flow_from_directory(
        'test',
        target_size=(150, 150),
        batch_size=6,
        class_mode='binary',
        shuffle=False)
# Out:
# Found 32 images belonging to 2 classes.
# Found 45 images belonging to 2 classes.
# Found 9 images belonging to 2 classes.

# %%
batch = train_gen.next()
batch[0][0]
batch[1][0]
# Out:
# 0.0

# %%
train_batches = int(train_gen.samples / train_gen.batch_size) * 5
val_batches = int(val_gen.samples / val_gen.batch_size)

# %%
def f1(y_true, y_pred):
    y_pred = K.round(y_pred)
    tp = K.sum(K.cast(y_true*y_pred, 'float'), axis=0)
    tn = K.sum(K.cast((1-y_true)*(1-y_pred), 'float'), axis=0)
    fp = K.sum(K.cast((1-y_true)*y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true*(1-y_pred), 'float'), axis=0)

    p = tp / (tp + fp + K.epsilon())
    r = tp / (tp + fn + K.epsilon())

    f1 = 2*p*r / (p+r+K.epsilon())
    f1 = tf.where(tf.math.is_nan(f1), tf.zeros_like(f1), f1)
    return K.mean(f1)

# %%
input_shape=(150, 150, 3)

# %%
model = Sequential()

model.add(Conv2D(filters=16, kernel_size=3, padding='valid', activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=2)) 
model.add(Conv2D(filters=32, kernel_size=3, padding='valid', activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='softmax'))

opt = optimizers.Nadam()
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['binary_accuracy', f1]) 
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 36, 36, 32)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               10617088
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 10,622,433
# Trainable params: 10,622,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(generator=train_gen, validation_data=val_gen, verbose=1, epochs=5, steps_per_epoch=train_batches, validation_steps=val_batches)
# Out:
# Epoch 1/5
# 25/25 [==============================] - 17s 696ms/step - loss: 10.4393 - binary_accuracy: 0.2985 - f1: 0.4457 - val_loss: 9.4920 - val_binary_accuracy: 0.3810 - val_f1: 0.5293
# Epoch 2/5
# 25/25 [==============================] - 15s 612ms/step - loss: 10.8179 - binary_accuracy: 0.3231 - f1: 0.4154 - val_loss: 9.4920 - val_binary_accuracy: 0.3810 - val_f1: 0.5293
# Epoch 3/5
# 25/25 [==============================] - 17s 676ms/step - loss: 10.3333 - binary_accuracy: 0.3116 - f1: 0.4781 - val_loss: 9.4920 - val_binary_accuracy: 0.3810 - val_f1: 0.5293
# Epoch 4/5
# 25/25 [==============================] - 17s 662ms/step - loss: 10.3310 - binary_accuracy: 0.3154 - f1: 0.4733 - val_loss: 9.4920 - val_binary_accuracy: 0.3810 - val_f1: 0.5293
# Epoch 5/5
# 25/25 [==============================] - 17s 673ms/step - loss: 10.4305 - binary_accuracy: 0.3134 - f1: 0.4638 - val_loss: 9.4920 - val_binary_accuracy: 0.3810 - val_f1: 0.5293

# %%
for i in range(3):
   plt.imshow(batch[0][i])
   plt.show()

# %%
fig, ax1 = plt.subplots(1,1,figsize=(12,7))
ax1.plot(history.epoch, history.history['loss'], marker='^', color='purple')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss', color='purple')
ax1.tick_params('y', colors='purple')

ax2 = ax1.twinx()
plt.plot(history.epoch, history.history['binary_accuracy'], marker='+', color='green', label='train')
ax2.set_ylim(0,1)

ax3 = ax1.twinx()
plt.plot(history.epoch, history.history['val_binary_accuracy'], marker='*', color='red', label='validation')
ax3.set_ylim(0,1)

fig.legend();
model.evaluate(train_gen, val_gen)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-9d0fee668794> in <module>
#      14
#      15 fig.legend();
# ---> 16 model.evaluate(train_gen, val_gen)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     999     # or a non-distributed Dataset or iterator in eager execution.
#    1000     if data_utils.is_generator_or_sequence(x):
# -> 1001       training_utils.check_generator_arguments(y, sample_weight)
#    1002       return self.evaluate_generator(
#    1003           x,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_utils.py in check_generator_arguments(y, sample_weight, validation_split)
#     966   """Validates arguments passed when using a generator."""
#     967   if y is not None:
# --> 968     raise ValueError('`y` argument is not supported when data is'
#     969                      'a generator or Sequence instance. Instead pass targets'
#     970                      ' as the second element of the generator.')
#
# ValueError: `y` argument is not supported when data isa generator or Sequence instance. Instead pass targets as the second element of the generator.

# %%
model.evaluate_generator(test_gen)
# Out:
# [7.666618824005127, 0.33333334, 0.5]

# %%
batch = test_gen.next()

images = batch[0]
labels = batch[1]
y = np.array([np.argmax(l) for l in labels])
y_hat = model.predict_classes(images)

fig = plt.figure(figsize=(20, 12))
for i in bad_indexes:
    ax = fig.add_subplot(4, 8, i + 1)
    ax.imshow(images[i])
    ax.axis('off')
    real = targets[str(y[i] + 1)]
    guess = targets[str(y_hat[i] + 1)]
    ax.set_title("{0}\n{1}".format(real, guess))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-adc460027c3d> in <module>
#       7
#       8 fig = plt.figure(figsize=(20, 12))
# ----> 9 for i in bad_indexes:
#      10     ax = fig.add_subplot(4, 8, i + 1)
#      11     ax.imshow(images[i])
#
# NameError: name 'bad_indexes' is not defined
